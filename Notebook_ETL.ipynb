# %%
# %run etl.py
# Out:
# STARTED ETL pipeline (to process song_data and log_data)             at 2021-02-19 01:32:04.872427
#
# Start processing song_data JSON files...
# Reading song_data files from s3a://udacity-dend/song_data/A/B/C/TRABCEI128F424C983.json...
# Song_data schema:
# root
#  |-- artist_id: string (nullable = true)
#  |-- artist_latitude: string (nullable = true)
#  |-- artist_location: string (nullable = true)
#  |-- artist_longitude: string (nullable = true)
#  |-- artist_name: string (nullable = true)
#  |-- duration: double (nullable = true)
#  |-- num_songs: long (nullable = true)
#  |-- song_id: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- year: long (nullable = true)
#
# Songs_table schema:
# root
#  |-- song_id: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- artist_id: string (nullable = true)
#  |-- year: long (nullable = true)
#  |-- duration: double (nullable = true)
#
# ...
